# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data=genfromtxt('un.dat',delimiter="\t")
len(data)
# Out:
# 101

# %%
x=data[1:,0]
y=data[1:,1]
print len(x)
print len(y)
# Out:
# 100
# 100

# %%
figure(figsize=[8,8])
scatter(x,y)
xlim([0,1])
ylim([0,1])
show()
