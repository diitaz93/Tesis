# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data=genfromtxt('un.dat',delimiter="\t")
N=len(data[0,:])-1
N
# Out:
# 100

# %%
x0=data[0,:N]
y0=data[1,:N]
a0=data[2,:N]
xf=data[3,:N]
yf=data[4,:N]
af=data[5,:N]
#print x0
#print y0
#print a0
#print xf
#print yf
print af
# Out:
# [ 3.9362  3.9286  3.9286  4.0162  3.9286  3.835   3.9286  3.924   3.9286
#   3.8996  3.835   3.9286  4.0085  3.9286  3.9286  3.9286  3.9286  4.0015
#   3.992   3.9286  3.9286  3.9333  3.9286  3.6177  3.9286  3.9286  3.8107
#   3.9286  3.9286  3.8923  3.9286  3.9286  3.9286  3.835   3.9286  3.9286
#   3.7253  3.9286  3.9632  3.9286  3.9286  3.8923  3.536   4.0015  3.9286
#   3.634   3.9286  3.9286  3.9286  3.9286  3.9056  3.9286  3.9286  3.9325
#   3.9286  3.9286  3.9286  3.835   3.9286  3.8543  4.0162  3.9286  3.9286
#   3.9286  3.889   3.9286  3.9286  4.2192  3.9286  3.9286  3.9286  4.0162
#   3.9286  3.9286  3.9286  3.9286  3.9286  3.835   3.8502  3.9229  3.8763
#   3.9286  3.9286  3.9286  3.9286  3.9286  3.9286  3.9286  3.9286  4.0162
#   3.9286  3.8763  4.1825  3.9286  3.9286  4.0426  3.924   3.9286  3.6449
#   3.9286]

# %%
U0=cos(a0)
V0=sin(a0)
Uf=cos(af)
Vf=sin(af)
C=range(1,N+1)

fig, ax = subplots()
ax.quiver(x0,y0,U0,V0,C)
ax.axis([-0.5,1.5,-0.5,1.5])
fig, ax = subplots()
ax.quiver(xf,yf,Uf,Vf,C)
ax.axis([-0.5,1.5,-0.5,1.5])
# Out:
# [-0.5, 1.5, -0.5, 1.5]

# %%
x=[4.0,7.0,4.5]
y=[3.0,1.0,5.5]
u=[1,1,1]
v=[1,1,1]
fig, ax = subplots()
ax.quiver(x,y,u,v)
ax.scatter(x,y,color='k')
ax.axis([0,10,0,10])
# Out:
# [0, 10, 0, 10]
